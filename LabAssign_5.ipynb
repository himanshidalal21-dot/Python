# %% [markdown]
# <a href="https://colab.research.google.com/github/himanshidalal21-dot/Python/blob/main/LabAssign_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nums = tuple(map(int, input("Enter integers: ").split()))

print("Total items:", len(nums))

print("Last item:", nums[-1])

print("Reverse order:", nums[::-1])

print("Yes" if 5 in nums else "No")

if len(nums) > 2:
    remaining_sorted = tuple(sorted(nums[1:-1]))
    print("Sorted remaining items:", remaining_sorted)
else:
    print("Not enough items to remove first and last.")
# Out:
# Enter integers: 5
# Total items: 1
# Last item: 5
# Reverse order: (5,)
# Yes
# Not enough items to remove first and last.

# %%
prices = tuple(map(float, input("Enter prices of sold items: ").split()))

print("Total items sold:", len(prices))

print("Cheapest item price:", min(prices))

max_price = max(prices)
print("Costliest item price:", max_price)

print("Prices in ascending order:", tuple(sorted(prices)))

count_max = prices.count(max_price)
print("Number of costliest items sold:", count_max)
# Out:
# Enter prices of sold items: 3 5 6 7
# Total items sold: 4
# Cheapest item price: 3.0
# Costliest item price: 7.0
# Prices in ascending order: (3.0, 5.0, 6.0, 7.0)
# Number of costliest items sold: 1
